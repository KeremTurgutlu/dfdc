# %%
import numpy as np

# %%
sum([330, 352]) / sum([1829, 330, 352, 9856])
# Out:
# 0.05514676154281556

# %%
clip = np.arange(0.5, 1, 0.01)

# %%
error_rate = 0.1

# %%
dict(zip(clip, -(error_rate*(np.log(1-clip)) + (1-error_rate)*(np.log(clip)))))
# Out:
# {0.5: 0.6931471805599453,
#  0.51: 0.6773450867251356,
#  0.52: 0.6619307381740176,
#  0.53: 0.6468927036201759,
#  0.54: 0.6322204044313349,
#  0.55: 0.6179040703018356,
#  0.56: 0.603934700934631,
#  0.5700000000000001: 0.5903040333676399,
#  0.5800000000000001: 0.5770045146679771,
#  0.5900000000000001: 0.5640292798025129,
#  0.6000000000000001: 0.551372134576807,
#  0.6100000000000001: 0.5390275436191465,
#  0.6200000000000001: 0.5269906234748702,
#  0.6300000000000001: 0.5152571409712894,
#  0.6400000000000001: 0.5038235171187755,
#  0.6500000000000001: 0.49268683693307647,
#  0.6600000000000001: 0.48184486570269214,
#  0.6700000000000002: 0.4712960723895737,
#  0.6800000000000002: 0.4610396610496225,
#  0.6900000000000002: 0.4510756114020431,
#  0.7000000000000002: 0.4414047299774526,
#  0.7100000000000002: 0.4320287136522599,
#  0.7200000000000002: 0.422950227856121,
#  0.7300000000000002: 0.4141730023541063,
#  0.7400000000000002: 0.4057019483021902,
# ...
